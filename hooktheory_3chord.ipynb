# %%
# Dependencies
import json
import requests
import time
import pandas as pd
from config import username, pword

# %%
# Request credentials using username and password
url = "https://api.hooktheory.com/v1/users/auth"
header = {"accept": "application/json", 
          "Content-Type": "application/json",
          "username": username,
          "password": pword}

response = requests.post(url, data=header).json()

#save the key and id from response
key = response['activkey']
user_id = response['id']

#create header used for queries
bearer = f'Bearer {key}'
a_header = {'Authorization':bearer}

# %%
c = requests.session()
c.headers = a_header

# %%
#set query url and parameters
url = "https://api.hooktheory.com/v1/trends/songs"
params = {'cp':'', 'page':1}

#list progressions we want to check
chords_df = pd.read_csv('Resources/3_chords.csv', header=None)
progressions = chords_df[0].values.tolist()

#initialize a list to store data
songs = []

# %%
comm = '''params['cp'] = progressions[0]
r = c.get(url, params = params)
response = r.json()
r.headers['X-Rate-Limit-Reset']'''

# %%
for cp in progressions:
    params['cp'] = cp
    page = 1
    while page > 0:
        params['page'] = page
        r = c.get(url, params = params)
        count = int(r.headers['X-Rate-Limit-Remaining'])
        if count == 0:
            wait = int(r.headers['X-Rate-Limit-Reset'])
            print(len(songs))
            time.sleep(wait)
        response = r.json()
        if len(response) == 0:
            page = 0
        else:
            for song in response:
                try:
                    song['cp'] = cp
                    songs.append(song)
                except:
                    pass
            page += 1
# Out:
# 120
# 260
# 400
# 540
# 680
# 785
# 925
# 1085
# 1225
# 1342
# 1482
# 1622
# 1737
# 1857
# 1973
# 2093
# 2233
# 2373
# 2477
# 2617
# 2757
# 2897
# 3010
# 3150
# 3255
# 3395
# 3535
# 3616
# 3756
# 3886
# 3994
# 4075
# 4215
# 4328
# 4418
# 4534
# 4650
# 4790
# 4910
# 5090
# 5230
# 5350
# 5530
# 5670
# 5806
# 5926
# 6086
# 6173
# 6313
# 6445
# 6565
# 6685
# 6825
# 6945
# 7085
# 7205
# 7345
# 7456
# 7596
# 7736
# 7876
# 8016
# 8176
# 8260
# 8440
# 8572
# 8667
# 8827
# 8987
# 9090
# 9230
# 9340
# 9458
# 9598
# 9758
# 9918
# 10078
# 10218
# 10418
# 10538
# 10678
# 10818
# 10933
# 11073
# 11191
# 11292
# 11432
# 11572
# 11712
# 11872
# 12032
# 12160
# 12280
# 12498
# 12616
# 12753
# 12933
# 13032
# 13172
# 13289
# 13418
# 13530
# 13665
# 13782
# 13918
# 14046
# 14236
# 14323
# 14424
# 14544
# 14684
# 14844
# 14984
# 15124
# 15264
# 15367
# 15527
# 15687
# 15776
# 15916
# 16023
# 16163
# 16266
# 16406
# 16546
# 16686
# 16823
# 16943
# 17083
# 17202
# 17362
# 17492
# 17594
# 17706
# 17866
# 17986
# 18146
# 18233
# 18393
# 18513
# 18653
# 18759
# 18899
# 19006
# 19125
# 19265
# 19384
# 19504
# 19612

# %%
songs_df = pd.DataFrame(songs)
songs_df = songs_df.drop(columns='url')
songs_df.head(30)
# Out:
#                  artist     cp       section                             song
# 0          3 Doors Down  1,5,6         Intro                     Be Like That
# 1          3 Doors Down  1,5,6         Verse                     Be Like That
# 2                 Adele  1,5,6        Chorus                 Someone Like You
# 3             Aerosmith  1,5,6         Verse                           Cryin'
# 4            Ai Ootsuka  1,5,6        Chorus                        Sakuranbo
# 5        Arctic Monkeys  1,5,6        Chorus                        Mardy Bum
# 6         Avril Lavigne  1,5,6        Chorus                       Girlfriend
# 7        Blues Traveler  1,5,6         Verse                             Hook
# 8              Bon Jovi  1,5,6        Chorus               Living On A Prayer
# 9            Bruno Mars  1,5,6        Chorus                          Grenade
# 10     Carly Rae Jepsen  1,5,6        Chorus                    Call Me Maybe
# 11     Carrie Underwood  1,5,6        Chorus                         So Small
# 12     Carrie Underwood  1,5,6         Verse                         So Small
# 13              Cascada  1,5,6        Chorus              Every Time We Touch
# 14              Cascada  1,5,6         Verse              Every Time We Touch
# 15          Cheryl Cole  1,5,6         Verse                        Parachute
# 16      Christina Perri  1,5,6        Chorus                    Jar Of Hearts
# 17               daudre  1,5,6        Chorus                        Sandstorm
# 18  Death Cab for Cutie  1,5,6        Chorus  I Will Follow You Into the Dark
# 19           Don McLean  1,5,6        Chorus                     American Pie
# 20              Erasure  1,5,6    Pre-Chorus                           Always
# 21              Erasure  1,5,6         Verse                           Always
# 22          Evanescence  1,5,6        Chorus                 Bring Me To Life
# 23             Flo Rida  1,5,6  Instrumental                          Whistle
# 24            Green Day  1,5,6         Verse                       Basketcase
# 25         Jack Johnson  1,5,6        Chorus                            Flake
# 26           Jason Mraz  1,5,6        Chorus                        I'm Yours
# 27           Jason Mraz  1,5,6         Verse                        I'm Yours
# 28           Katy Perry  1,5,6        Chorus                         Firework
# 29       Kelly Clarkson  1,5,6        Chorus                     Already Gone

# %%
songs_df.to_csv('3chord_songs.csv', index=False, header=True)

# %%
songs_df.tail(30)
# Out:
#                         artist     cp               section  \
# 19649               Koji Kondo  5,2,3                 Verse
# 19650              John Martin  5,2,3                Chorus
# 19651        Infected Mushroom  5,2,3                 Verse
# 19652               Aloe Blacc  5,2,3                Chorus
# 19653                     Vlad  5,2,3  Verse and Pre-Chorus
# 19654                   Darude  5,2,3                 Verse
# 19655                    Nhato  5,2,3                Bridge
# 19656           Friendly Fires  5,2,3                Chorus
# 19657               Eric Prydz  5,2,3                 Verse
# 19658            Flip and Fill  5,2,3                 Verse
# 19659         Serge Gainsbourg  5,2,3                 Verse
# 19660              Sy And Demo  5,2,3                Chorus
# 19661              Varius Manx  5,2,3                Chorus
# 19662                   Boston  5,2,3                Bridge
# 19663                 Animusic  5,2,3                Solo 1
# 19664                  Rihanna  5,2,3                Bridge
# 19665                     Zedd  5,2,3                 Verse
# 19666              Jay Hardway  5,2,3                Chorus
# 19667  Nikolai Rimsky-Korsakov  5,2,3                Chorus
# 19668              Keri Hilson  5,2,3                Chorus
# 19669                      Au5  5,2,3                Chorus
# 19670             Lana Del Rey  5,2,3                Bridge
# 19671                Brand New  5,2,3            Pre-Chorus
# 19672                  Rihanna  5,2,3                Chorus
# 19673                  Rihanna  5,2,3                 Intro
# 19674                Relient K  5,2,3                 Verse
# 19675                Ladyhawke  5,2,3            Pre-Chorus
# 19676                  Phoenix  5,2,3                Chorus
# 19677                    Wilco  5,2,3                 Intro
# 19678                     Emax  5,2,3                Chorus
#
#                                   song
# 19649   Super Mario 64 - Bowser's Road
# 19650                 Anywhere For You
# 19651                      Muse Breaks
# 19652                  I Need A Dollar
# 19653                        Magicka 2
# 19654                    Feel The Beat
# 19655                         Miss You
# 19656                     Kiss Of Life
# 19657                           Pjanoo
# 19658                       Irish Blue
# 19659         Je t'aime - moi non plus
# 19660                     Stay With Me
# 19661              Piosenka ksiezycowa
# 19662                    Peace of Mind
# 19663                      Heavy Light
# 19664                        Disturbia
# 19665                   Done With Love
# 19666               Electric Elephants
# 19667         Procession Of The Nobles
# 19668                     Lose Control
# 19669                            Virgo
# 19670                             Ride
# 19671                Failure by Design
# 19672                             Work
# 19673                             Work
# 19674                     Be My Escape
# 19675                      My Delirium
# 19676         Everything Is Everything
# 19677  I Am Trying to Break Your Heart
# 19678                    Delicate Oooz
