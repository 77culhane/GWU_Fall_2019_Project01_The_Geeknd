# %%
# Dependencies
import json
import requests
import time
import pandas as pd
from config import pword
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-18b60ca7a1cc> in <module>
#       4 import time
#       5 import pandas as pd
# ----> 6 from config import pword
#
# ModuleNotFoundError: No module named 'config'

# %%
# Request credentials using username and password
url = "https://api.hooktheory.com/v1/users/auth"
header = {"accept": "application/json", 
          "Content-Type": "application/json",
          "username": 'mgtsn',
          "password": pword}

response = requests.post(url, data=header).json()

#save the key and id from response
key = response['activkey']
user_id = response['id']

#create header used for queries
bearer = f'Bearer {key}'
a_header = {'Authorization':bearer}

# %%
c = requests.session()
c.headers = a_header

# %%
#set query url and parameters
url = "https://api.hooktheory.com/v1/trends/songs"
params = {'cp':'', 'page':1}

#list progressions we want to check
progressions = ['1,5,4,6', '1,4,5', '1,4,6,5', '6,4,1,5', '1,6,4,5']

#initialize a list to store data
songs = []

# %%
comm = '''params['cp'] = progressions[0]
r = c.get(url, params = params)
response = r.json()
r.headers['X-Rate-Limit-Reset']'''

# %%
for cp in progressions:
    params['cp'] = cp
    page = 1
    while page > 0:
        params['page'] = page
        r = c.get(url, params = params)
        count = int(r.headers['X-Rate-Limit-Remaining'])
        if count == 0:
            wait = int(r.headers['X-Rate-Limit-Reset'])
            print(len(songs))
            time.sleep(wait)
        response = r.json()
        if len(response) == 0:
            page = 0
        else:
            for song in response:
                try:
                    song['cp'] = cp
                    songs.append(song)
                except:
                    pass
            page += 1

# %%
songs_df = pd.DataFrame(songs)
songs_df = songs_df.drop(columns='url')
songs_df.head(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-727c05d2c875> in <module>
# ----> 1 songs_df = pd.DataFrame(songs)
#       2 songs_df = songs_df.drop(columns='url')
#       3 songs_df.head(30)
#
# NameError: name 'songs' is not defined

# %%
songs_df.to_csv('hooktheory_output.csv', index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b32767eee78b> in <module>
# ----> 1 songs_df.to_csv('hooktheory_output.csv', index=False, header=True)
#
# NameError: name 'songs_df' is not defined

# %%
songs_df.tail(30)
# Out:
#                            artist       cp                section  \
# 1294                    PewDiePie  1,6,4,5                 Chorus
# 1295           Fountains of Wayne  1,6,4,5                  Verse
# 1296                 Van Morrison  1,6,4,5                  Verse
# 1297                 Taylor Swift  1,6,4,5                  Verse
# 1298                     Paramore  1,6,4,5  Pre-Chorus and Chorus
# 1299  Bubbles and the Shitrockers  1,6,4,5                   Solo
