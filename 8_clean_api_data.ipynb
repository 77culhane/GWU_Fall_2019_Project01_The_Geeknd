# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
# Import data retrieved from HookTheory API
hook_data = pd.read_csv('chords_all_songs.csv')
hook_data = hook_data.drop(columns='Unnamed: 0')
hook_data.head()
# Out:
#          artist     cp section              song     type
# 0  3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 1  3 Doors Down  1,5,6   Verse      Be Like That  3 chord
# 2         Adele  1,5,6  Chorus  Someone Like You  3 chord
# 3     Aerosmith  1,5,6   Verse            Cryin'  3 chord
# 4    Ai Ootsuka  1,5,6  Chorus         Sakuranbo  3 chord

# %%
# Display size of dataframe
len(hook_data)
# Out:
# 48935

# %%
# Import data retrieved from last.fm and spotify for unique songs subset of HookTheory data
stats = pd.read_csv('spotify_data.csv')
stats.head()
# Out:
#               0     cp          section                     song     type  \
# 0      73113243  1,2,3           Chorus                 NYAN CAT  3 chord
# 1          10cc  4,5,6  Intro and Verse  The Wall Street Shuffle  3 chord
# 2          1927  1,4,5  Intro and Verse               If I Could  3 chord
# 3          2pac  4,1,5            Verse                  Changes  3 chord
# 4  3 Doors Down  1,5,6            Intro             Be Like That  3 chord
#
#             song (last.fm) artist (last.fm)  listener count (last.fm)  \
# 0                      NaN              NaN                       NaN
# 1  The Wall Street Shuffle             10cc                   66115.0
# 2               If I Could             1927                    4020.0
# 3                  Changes             2Pac                  315181.0
# 4             Be Like That     3 Doors Down                  403366.0
#
#    play count (last.fm)                                    genre (last.fm)  \
# 0                   NaN                                                NaN
# 1              210783.0                 rock, classic rock, 70s, 10cc, pop
# 2               21222.0                    australian, pop, rock, 80s, AOR
# 3             2046155.0           rap, Hip-Hop, hip hop, 2pac, Gangsta Rap
# 4             1913091.0  rock, alternative rock, 3 Doors Down, alternat...
#
#             song (Spotify) artist (Spotify)  popularity (Spotify)  \
# 0                      NaN              NaN                   NaN
# 1  The Wall Street Shuffle             10cc                  49.0
# 2                      NaN              NaN                   NaN
# 3                  Changes             2Pac                  64.0
# 4             Be Like That     3 Doors Down                  60.0
#
#   release date (Spotify)
# 0                    NaN
# 1             2004-01-01
# 2                    NaN
# 3             1998-01-01
# 4                   2000

# %%
# Rename first column as 'artist'
stats = stats.rename(columns={'0':'artist'})

# Create a truncated dataframe
lastfm_raw = stats[['artist',
                       'song',
                       'listener count (last.fm)',
                       'play count (last.fm)',
                       'genre (last.fm)']]

# Drop null entries from dataframe
lastfm_raw = lastfm_raw.dropna(how='any')
lastfm_raw.head()
# Out:
#          artist                     song  listener count (last.fm)  \
# 1          10cc  The Wall Street Shuffle                   66115.0
# 2          1927               If I Could                    4020.0
# 3          2pac                  Changes                  315181.0
# 4  3 Doors Down             Be Like That                  403366.0
# 5  3 Doors Down               Kryptonite                 1067856.0
#
#    play count (last.fm)                                    genre (last.fm)
# 1              210783.0                 rock, classic rock, 70s, 10cc, pop
# 2               21222.0                    australian, pop, rock, 80s, AOR
# 3             2046155.0           rap, Hip-Hop, hip hop, 2pac, Gangsta Rap
# 4             1913091.0  rock, alternative rock, 3 Doors Down, alternat...
# 5             7265039.0  rock, alternative rock, 3 Doors Down, alternat...

# %%
# Separate genre data for each song into individual rows
lastfm_genre = pd.DataFrame(lastfm_raw['genre (last.fm)'].str.split(', ').tolist(),index=lastfm_raw['song']).stack()
lastfm_genre
# Out:
# song
# The Wall Street Shuffle      0                rock
#                              1        classic rock
#                              2                 70s
#                              3                10cc
#                              4                 pop
# If I Could                   0          australian
#                              1                 pop
#                              2                rock
#                              3                 80s
#                              4                 AOR
# Changes                      0                 rap
#                              1             Hip-Hop
#                              2             hip hop
#                              3                2pac
#                              4         Gangsta Rap
# Be Like That                 0                rock
#                              1    alternative rock
#                              2        3 Doors Down
#                              3         alternative
#                              4        Be Like That
# Kryptonite                   0                rock
#                              1    alternative rock
#                              2        3 Doors Down
#                              3         alternative
#                              4           hard rock
# Amber                        0              reggae
#                              1               chill
#                              2              Mellow
#                              3         alternative
#                              4                rock
#                                         ...
# boyfriend                    3                2012
#                              4            biebstep
# Only You                     0              Korean
#                              1               k-pop
#                              2                Kpop
#                              3        best of 2015
#                              4      Makes me dance
# Sugar Rush                   0            hardcore
#                              1      happy hardcore
# rainbow road                 0      happy hardcore
#                              1          electronic
#                              2            hardcore
#                              3              techno
# Nice Guys                    0           nice guys
# Kimi No Shiranai Monogatari  0               anime
#                              1            japanese
#                              2      bakemonogatari
#                              3                rock
#                              4              J-rock
# All About Us                 0                 pop
#                              1                good
#                              2                rock
#                              3             lesbian
#                              4                 hot
# Satisfied in You             0           mars hill
# Phiesope                     0          electronic
#                              1                 idm
#                              2             ambient
#                              3            chillout
#                              4             british
# Length: 15413, dtype: object

# %%
# Reset index to resulting dataframe
lastfm_genre = lastfm_genre.reset_index([0,'song'])

# Assign column headers
lastfm_genre.columns = ['song','genre (last.fm)']
lastfm_genre.head()
# Out:
#                       song genre (last.fm)
# 0  The Wall Street Shuffle            rock
# 1  The Wall Street Shuffle    classic rock
# 2  The Wall Street Shuffle             70s
# 3  The Wall Street Shuffle            10cc
# 4  The Wall Street Shuffle             pop

# %%
# Drop original genre column from original dataframe and merge with new dataframe
lastfm_raw = lastfm_raw.drop(columns=['genre (last.fm)'])
lastfm_stats = pd.merge(lastfm_raw, lastfm_genre, how='outer', on='song')
lastfm_stats.head()
# Out:
#   artist                     song  listener count (last.fm)  \
# 0   10cc  The Wall Street Shuffle                   66115.0
# 1   10cc  The Wall Street Shuffle                   66115.0
# 2   10cc  The Wall Street Shuffle                   66115.0
# 3   10cc  The Wall Street Shuffle                   66115.0
# 4   10cc  The Wall Street Shuffle                   66115.0
#
#    play count (last.fm) genre (last.fm)
# 0              210783.0            rock
# 1              210783.0    classic rock
# 2              210783.0             70s
# 3              210783.0            10cc
# 4              210783.0             pop

# %%
# Determine if the values for artist and genre for each row match
# if lastfm_stats.loc[3,'artist'] == lastfm_stats.loc[3,'genre (last.fm)']:
#     print('True')
# else:
#     print('False')

# %%
# Inititalize list of index information for rows to be dropped from dataframe
droplist = []

# Use for loop to determine if either the artist name or the song name matches the genre for each row
# If either condition is met, add index number to droplist list
for song in range(len(lastfm_stats)):
    artist = lastfm_stats.loc[song,'artist']
    track = lastfm_stats.loc[song,'song']
    genre = lastfm_stats.loc[song,'genre (last.fm)']
    if (artist == genre) | (track == genre):
        droplist.append(song)

# Drop dataframe entries based on index information contained in droplist list
lastfm_stats.drop(droplist,inplace=True)
lastfm_stats.head()
# Out:
#   artist                     song  listener count (last.fm)  \
# 0   10cc  The Wall Street Shuffle                   66115.0
# 1   10cc  The Wall Street Shuffle                   66115.0
# 2   10cc  The Wall Street Shuffle                   66115.0
# 4   10cc  The Wall Street Shuffle                   66115.0
# 5   1927               If I Could                    4020.0
#
#    play count (last.fm) genre (last.fm)
# 0              210783.0            rock
# 1              210783.0    classic rock
# 2              210783.0             70s
# 4              210783.0             pop
# 5               21222.0      australian

# %%
# Create a truncated dataframe
spotify_stats = stats[['artist',
                       'song',
                       'popularity (Spotify)',
                       'release date (Spotify)']]

# Drop null entries from dataframe
spotify_stats = spotify_stats.dropna(how='any')
spotify_stats.head()
# Out:
#          artist                     song  popularity (Spotify)  \
# 1          10cc  The Wall Street Shuffle                  49.0
# 3          2pac                  Changes                  64.0
# 4  3 Doors Down             Be Like That                  60.0
# 5  3 Doors Down               Kryptonite                  79.0
# 6           311                    Amber                  67.0
#
#   release date (Spotify)
# 1             2004-01-01
# 3             1998-01-01
# 4                   2000
# 5                   2000
# 6             2004-06-08

# %%
# Display size of dataframe
len(stats)
# Out:
# 4773

# %%
# Convert release date entries to datetime type and format to show only year
spotify_stats['release date (Spotify)'] = pd.to_datetime(spotify_stats['release date (Spotify)'])
spotify_stats['release date (Spotify)'] = pd.DatetimeIndex(spotify_stats['release date (Spotify)']).year
spotify_stats.head()
# Out:
#          artist                     song  popularity (Spotify)  \
# 1          10cc  The Wall Street Shuffle                  49.0
# 3          2pac                  Changes                  64.0
# 4  3 Doors Down             Be Like That                  60.0
# 5  3 Doors Down               Kryptonite                  79.0
# 6           311                    Amber                  67.0
#
#    release date (Spotify)
# 1                    2004
# 3                    1998
# 4                    2000
# 5                    2000
# 6                    2004

# %%
# Merge full HookTheory data set with last.fm data
combined_lastfm = pd.merge(hook_data, lastfm_stats, how='left', on=['artist','song'])
combined_lastfm.head()
# Out:
#          artist     cp section          song     type  \
# 0  3 Doors Down  1,5,6   Intro  Be Like That  3 chord
# 1  3 Doors Down  1,5,6   Intro  Be Like That  3 chord
# 2  3 Doors Down  1,5,6   Intro  Be Like That  3 chord
# 3  3 Doors Down  1,5,6   Verse  Be Like That  3 chord
# 4  3 Doors Down  1,5,6   Verse  Be Like That  3 chord
#
#    listener count (last.fm)  play count (last.fm)   genre (last.fm)
# 0                  403366.0             1913091.0              rock
# 1                  403366.0             1913091.0  alternative rock
# 2                  403366.0             1913091.0       alternative
# 3                  403366.0             1913091.0              rock
# 4                  403366.0             1913091.0  alternative rock

# %%
# Display size of dataframe
len(combined_lastfm)
# Out:
# 189221

# %%
# Drop duplicate entries from the merged dataframe using values from specific columns as criteria 
combined_lastfm = combined_lastfm.drop_duplicates(subset=['artist','cp','song','genre (last.fm)'])

# Cast listener count and play count data as integers
# combined_lastfm['listener count (last.fm)'] = combined_lastfm['listener count (last.fm)'].astype(int)
# combined_lastfm['play count (last.fm)'] = combined_lastfm['play count (last.fm)'].astype(int)

combined_lastfm.head()
# Out:
#          artist     cp section              song     type  \
# 0  3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 1  3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 2  3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 6         Adele  1,5,6  Chorus  Someone Like You  3 chord
# 7         Adele  1,5,6  Chorus  Someone Like You  3 chord
#
#    listener count (last.fm)  play count (last.fm)   genre (last.fm)
# 0                  403366.0             1913091.0              rock
# 1                  403366.0             1913091.0  alternative rock
# 2                  403366.0             1913091.0       alternative
# 6                 1023520.0            10250722.0              soul
# 7                 1023520.0            10250722.0             piano

# %%
# Display size of dataframe
len(combined_lastfm)
# Out:
# 164075

# %%
# Save resulting dataframe as a csv file
combined_lastfm.to_csv('combined_hook-lastfm.csv')

# %%
# Merge full HookTheory data set with Spotify data
combined_spotify = pd.merge(hook_data, spotify_stats, how='left', on=['artist','song'])

# Drop null entries from merged dataframe
combined_spotify = combined_spotify.dropna(how='any')

# Cast popularity and release data as integers
combined_spotify['release date (Spotify)'] = combined_spotify['release date (Spotify)'].astype(int)
combined_spotify['popularity (Spotify)'] = combined_spotify['popularity (Spotify)'].astype(int)

combined_spotify.head()
# Out:
#            artist     cp section              song     type  \
# 0    3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 1    3 Doors Down  1,5,6   Verse      Be Like That  3 chord
# 2           Adele  1,5,6  Chorus  Someone Like You  3 chord
# 3       Aerosmith  1,5,6   Verse            Cryin'  3 chord
# 5  Arctic Monkeys  1,5,6  Chorus         Mardy Bum  3 chord
#
#    popularity (Spotify)  release date (Spotify)
# 0                    60                    2000
# 1                    60                    2000
# 2                    80                    2011
# 3                    72                    1993
# 5                    59                    2006

# %%
# Display size of dataframe
len(combined_spotify)
# Out:
# 22518

# %%
# Save resulting dataframe as a csv file
combined_spotify.to_csv('combined_hook-spotify.csv')

# %%
# Drop duplicate entries from the merged dataframe using values from specific columns as criteria 
unique_spotify = combined_spotify.drop_duplicates(subset=['artist','song'])
unique_spotify.head()
# Out:
#            artist     cp section              song     type  \
# 0    3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 2           Adele  1,5,6  Chorus  Someone Like You  3 chord
# 3       Aerosmith  1,5,6   Verse            Cryin'  3 chord
# 5  Arctic Monkeys  1,5,6  Chorus         Mardy Bum  3 chord
# 6   Avril Lavigne  1,5,6  Chorus        Girlfriend  3 chord
#
#    popularity (Spotify)  release date (Spotify)
# 0                    60                    2000
# 2                    80                    2011
# 3                    72                    1993
# 5                    59                    2006
# 6                    74                    2007

# %%
# Create a truncated dataframe
sub_spotify = unique_spotify[['artist','song','popularity (Spotify)','release date (Spotify)']]
sub_spotify.head()
# Out:
#            artist              song  popularity (Spotify)  \
# 0    3 Doors Down      Be Like That                    60
# 2           Adele  Someone Like You                    80
# 3       Aerosmith            Cryin'                    72
# 5  Arctic Monkeys         Mardy Bum                    59
# 6   Avril Lavigne        Girlfriend                    74
#
#    release date (Spotify)
# 0                    2000
# 2                    2011
# 3                    1993
# 5                    2006
# 6                    2007

# %%
combined_all = pd.merge(combined_lastfm, sub_spotify, how='left', on=['artist','song'])
combined_all = combined_all.dropna(how='any')
combined_all['listener count (last.fm)'] = combined_all['listener count (last.fm)'].astype(int)
combined_all['play count (last.fm)'] = combined_all['play count (last.fm)'].astype(int)
combined_all['release date (Spotify)'] = combined_all['release date (Spotify)'].astype(int)
combined_all['popularity (Spotify)'] = combined_all['popularity (Spotify)'].astype(int)
combined_all.head()
# Out:
#          artist     cp section              song     type  \
# 0  3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 1  3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 2  3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 3         Adele  1,5,6  Chorus  Someone Like You  3 chord
# 4         Adele  1,5,6  Chorus  Someone Like You  3 chord
#
#    listener count (last.fm)  play count (last.fm)   genre (last.fm)  \
# 0                    403366               1913091              rock
# 1                    403366               1913091  alternative rock
# 2                    403366               1913091       alternative
# 3                   1023520              10250722              soul
# 4                   1023520              10250722             piano
#
#    popularity (Spotify)  release date (Spotify)
# 0                    60                    2000
# 1                    60                    2000
# 2                    60                    2000
# 3                    80                    2011
# 4                    80                    2011

# %%
# Display size of dataframe
len(combined_all)
# Out:
# 93111

# %%
# Save resulting dataframe as a csv file
combined_all.to_csv('combined_all.csv')

# %%
# Create a dataframe containing only one entry for each song 
combined_unique = combined_all.drop_duplicates(subset=['artist','song'])
combined_unique.head()
# Out:
#             artist     cp section              song     type  \
# 0     3 Doors Down  1,5,6   Intro      Be Like That  3 chord
# 3            Adele  1,5,6  Chorus  Someone Like You  3 chord
# 7        Aerosmith  1,5,6   Verse            Cryin'  3 chord
# 17  Arctic Monkeys  1,5,6  Chorus         Mardy Bum  3 chord
# 22   Avril Lavigne  1,5,6  Chorus        Girlfriend  3 chord
#
#     listener count (last.fm)  play count (last.fm) genre (last.fm)  \
# 0                     403366               1913091            rock
# 3                    1023520              10250722            soul
# 7                     567063               2970510            rock
# 17                   1101408               9505520      indie rock
# 22                    563039               3833402             pop
#
#     popularity (Spotify)  release date (Spotify)
# 0                     60                    2000
# 3                     80                    2011
# 7                     72                    1993
# 17                    59                    2006
# 22                    74                    2007

# %%
# Save resulting dataframe as a csv file
combined_unique.to_csv('combined_unique.csv')
