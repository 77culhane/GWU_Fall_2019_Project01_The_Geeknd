# %%
# Import dependencies
import pandas as pd
import requests
import io

# %%
# Read country code data and store in dataframe
countries = pd.read_csv('Resources/country_code.csv')
countries.head()
# Out:
#           country code
# 0   United States   us
# 1  United Kingdom   gb
# 2         Andorra   ad
# 3       Argentina   ar
# 4         Austria   at

# %%
# Initialize dictionary to store dataframes with information on top 200 songs for various countries
dataframe_dict = {}

# Assign target date/period to a variable
period = '2016-12-23--2016-12-30'

# Retrieve top 200 charts for various countries from Spotify Charts
# for i in range(0,1):  #use for testing
for i in range(len(countries)):
    
    # Assign country code for taget country (chart) to a variable and print message to indicate that request is underway
    country = countries.loc[i,'code']
    print(f"Retrieving Top 200 Chart for {countries.loc[i,'country']}...")
    
    # Assign target url for csv file to a variable.  Print url for information.
    # url = f'https://spotifycharts.com/regional/{country}/weekly/{period}/download'  #use for weekly charts
    url = f'https://spotifycharts.com/regional/{country}/daily/latest/download'  #use for daily charts
    print(f'    {url}')
    
    # Use requests.get to retrieve information from target csv
    r = requests.get(url)
    
    try:
          # Use 'utf-8' to allow for proper interpretation of retrieved data
          data = r.content.decode('utf-8')
          
          # Read and assign retrieved data to a dataframe
          chart = pd.read_csv(io.StringIO(data))
          
          # Assign resulting dataframe as an value/entry in dataframe_dict dictionary with the country name as the key
          dataframe_dict[countries.loc[i,'country']] = chart
          
          # Use first row of dataframe as column headers and delete row
          dataframe_dict[countries.loc[i,'country']].columns = dataframe_dict[countries.loc[i,'country']].iloc[0] 
          dataframe_dict[countries.loc[i,'country']] = dataframe_dict[countries.loc[i,'country']].drop(dataframe_dict[countries.loc[i,'country']].index[0])
          
          # Add a column to the dataframe to identify the country associated with the retrieved chart data
          dataframe_dict[countries.loc[i,'country']]['Chart'] = countries.loc[i,'country']
    
    except:
          print('    Error encountered...')
# Out:
# Retrieving Top 200 Chart for United States...
#     https://spotifycharts.com/regional/us/daily/latest/download
# Retrieving Top 200 Chart for United Kingdom...
#     https://spotifycharts.com/regional/gb/daily/latest/download
# Retrieving Top 200 Chart for Andorra...
#     https://spotifycharts.com/regional/ad/daily/latest/download
#     Error encountered...
# Retrieving Top 200 Chart for Argentina...
#     https://spotifycharts.com/regional/ar/daily/latest/download
# Retrieving Top 200 Chart for Austria...
#     https://spotifycharts.com/regional/at/daily/latest/download
# Retrieving Top 200 Chart for Australia...
#     https://spotifycharts.com/regional/au/daily/latest/download
# Retrieving Top 200 Chart for Belgium...
#     https://spotifycharts.com/regional/be/daily/latest/download
# Retrieving Top 200 Chart for Bulgaria...
#     https://spotifycharts.com/regional/bg/daily/latest/download
# Retrieving Top 200 Chart for Bolivia...
#     https://spotifycharts.com/regional/bo/daily/latest/download
# Retrieving Top 200 Chart for Brazil...
#     https://spotifycharts.com/regional/br/daily/latest/download
# Retrieving Top 200 Chart for Canada...
#     https://spotifycharts.com/regional/ca/daily/latest/download
# Retrieving Top 200 Chart for Switzerland...
#     https://spotifycharts.com/regional/ch/daily/latest/download
# Retrieving Top 200 Chart for Chile...
#     https://spotifycharts.com/regional/cl/daily/latest/download
# Retrieving Top 200 Chart for Colombia...
#     https://spotifycharts.com/regional/co/daily/latest/download
# Retrieving Top 200 Chart for Costa Rica...
#     https://spotifycharts.com/regional/cr/daily/latest/download
# Retrieving Top 200 Chart for Cyprus...
#     https://spotifycharts.com/regional/cy/daily/latest/download
#     Error encountered...
# Retrieving Top 200 Chart for Czech Republic...
#     https://spotifycharts.com/regional/cz/daily/latest/download
# Retrieving Top 200 Chart for Germany...
#     https://spotifycharts.com/regional/de/daily/latest/download
# Retrieving Top 200 Chart for Denmark...
#     https://spotifycharts.com/regional/dk/daily/latest/download
# Retrieving Top 200 Chart for Dominican Republic...
#     https://spotifycharts.com/regional/do/daily/latest/download
# Retrieving Top 200 Chart for Ecuador...
#     https://spotifycharts.com/regional/ec/daily/latest/download
# Retrieving Top 200 Chart for Estonia...
#     https://spotifycharts.com/regional/ee/daily/latest/download
# Retrieving Top 200 Chart for Spain...
#     https://spotifycharts.com/regional/es/daily/latest/download
# Retrieving Top 200 Chart for Finland...
#     https://spotifycharts.com/regional/fi/daily/latest/download
# Retrieving Top 200 Chart for France...
#     https://spotifycharts.com/regional/fr/daily/latest/download
# Retrieving Top 200 Chart for Greece...
#     https://spotifycharts.com/regional/gr/daily/latest/download
# Retrieving Top 200 Chart for Guatemala...
#     https://spotifycharts.com/regional/gt/daily/latest/download
# Retrieving Top 200 Chart for Hong Kong...
#     https://spotifycharts.com/regional/hk/daily/latest/download
# Retrieving Top 200 Chart for Honduras...
#     https://spotifycharts.com/regional/hn/daily/latest/download
# Retrieving Top 200 Chart for Hungary...
#     https://spotifycharts.com/regional/hu/daily/latest/download
# Retrieving Top 200 Chart for Indonesia...
#     https://spotifycharts.com/regional/id/daily/latest/download
# Retrieving Top 200 Chart for Ireland...
#     https://spotifycharts.com/regional/ie/daily/latest/download
# Retrieving Top 200 Chart for Israel...
#     https://spotifycharts.com/regional/il/daily/latest/download
# Retrieving Top 200 Chart for India...
#     https://spotifycharts.com/regional/in/daily/latest/download
# Retrieving Top 200 Chart for Iceland...
#     https://spotifycharts.com/regional/is/daily/latest/download
# Retrieving Top 200 Chart for Italy...
#     https://spotifycharts.com/regional/it/daily/latest/download
# Retrieving Top 200 Chart for Japan...
#     https://spotifycharts.com/regional/jp/daily/latest/download
# Retrieving Top 200 Chart for Lithuania...
#     https://spotifycharts.com/regional/lt/daily/latest/download
# Retrieving Top 200 Chart for Luxembourg...
#     https://spotifycharts.com/regional/lu/daily/latest/download
# Retrieving Top 200 Chart for Latvia...
#     https://spotifycharts.com/regional/lv/daily/latest/download
# Retrieving Top 200 Chart for Monaco...
#     https://spotifycharts.com/regional/mc/daily/latest/download
#     Error encountered...
# Retrieving Top 200 Chart for Malta...
#     https://spotifycharts.com/regional/mt/daily/latest/download
# Retrieving Top 200 Chart for Mexico...
#     https://spotifycharts.com/regional/mx/daily/latest/download
# Retrieving Top 200 Chart for Malaysia...
#     https://spotifycharts.com/regional/my/daily/latest/download
# Retrieving Top 200 Chart for Nicaragua...
#     https://spotifycharts.com/regional/ni/daily/latest/download
# Retrieving Top 200 Chart for Netherlands...
#     https://spotifycharts.com/regional/nl/daily/latest/download
# Retrieving Top 200 Chart for Norway...
#     https://spotifycharts.com/regional/no/daily/latest/download
# Retrieving Top 200 Chart for New Zealand...
#     https://spotifycharts.com/regional/nz/daily/latest/download
# Retrieving Top 200 Chart for Panama...
#     https://spotifycharts.com/regional/pa/daily/latest/download
# Retrieving Top 200 Chart for Peru...
#     https://spotifycharts.com/regional/pe/daily/latest/download
# Retrieving Top 200 Chart for Philippines...
#     https://spotifycharts.com/regional/ph/daily/latest/download
# Retrieving Top 200 Chart for Poland...
#     https://spotifycharts.com/regional/pl/daily/latest/download
# Retrieving Top 200 Chart for Portugal...
#     https://spotifycharts.com/regional/pt/daily/latest/download
# Retrieving Top 200 Chart for Paraguay...
#     https://spotifycharts.com/regional/py/daily/latest/download
# Retrieving Top 200 Chart for Romania...
#     https://spotifycharts.com/regional/ro/daily/latest/download
# Retrieving Top 200 Chart for Sweden...
#     https://spotifycharts.com/regional/se/daily/latest/download
# Retrieving Top 200 Chart for Singapore...
#     https://spotifycharts.com/regional/sg/daily/latest/download
# Retrieving Top 200 Chart for Slovakia...
#     https://spotifycharts.com/regional/sk/daily/latest/download
# Retrieving Top 200 Chart for El Salvador...
#     https://spotifycharts.com/regional/sv/daily/latest/download
# Retrieving Top 200 Chart for Thailand...
#     https://spotifycharts.com/regional/th/daily/latest/download
# Retrieving Top 200 Chart for Turkey...
#     https://spotifycharts.com/regional/tr/daily/latest/download
# Retrieving Top 200 Chart for Taiwan...
#     https://spotifycharts.com/regional/tw/daily/latest/download
# Retrieving Top 200 Chart for Uruguay...
#     https://spotifycharts.com/regional/uy/daily/latest/download
# Retrieving Top 200 Chart for Viet Nam...
#     https://spotifycharts.com/regional/vn/daily/latest/download
# Retrieving Top 200 Chart for South Africa...
#     https://spotifycharts.com/regional/za/daily/latest/download

# %%
# Generate list of keys (i.e., dataframes of top 200 chart information for various countries)
dataframe_dict.keys()
# Out:
# dict_keys(['United States', 'United Kingdom', 'Argentina', 'Austria', 'Australia', 'Belgium', 'Bulgaria', 'Bolivia', 'Brazil', 'Canada', 'Switzerland', 'Chile', 'Colombia', 'Costa Rica', 'Czech Republic', 'Germany', 'Denmark', 'Dominican Republic', 'Ecuador', 'Estonia', 'Spain', 'Finland', 'France', 'Greece', 'Guatemala', 'Hong Kong', 'Honduras', 'Hungary', 'Indonesia', 'Ireland', 'Israel', 'India', 'Iceland', 'Italy', 'Japan', 'Lithuania', 'Luxembourg', 'Latvia', 'Malta', 'Mexico', 'Malaysia', 'Nicaragua', 'Netherlands', 'Norway', 'New Zealand', 'Panama', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Paraguay', 'Romania', 'Sweden', 'Singapore', 'Slovakia', 'El Salvador', 'Thailand', 'Turkey', 'Taiwan', 'Uruguay', 'Viet Nam', 'South Africa'])

# %%
# Consolidate top 200 chart information from various countries into one dataframe
for key in dataframe_dict:
    
    if key == 'United States':
        spotify_charts = dataframe_dict[key]
    else:
        spotify_charts = spotify_charts.append(dataframe_dict[key])

spotify_charts
# Out:
# 0   Position                                         Track Name  \
# 1          1                                Lose You To Love Me
# 2          2                                         Follow God
# 3          3                                            Circles
# 4          4                                HIGHEST IN THE ROOM
# 5          5           Bandit (with YoungBoy Never Broke Again)
# 6          6                                  Someone You Loved
# 7          7                                           Memories
# 8          8                                    hot girl bummer
# 9          9                                             On God
# 10        10                                       Dance Monkey
# 11        11                                   Closed On Sunday
# 12        12                                    Look At Her Now
# 13        13                                              Selah
# 14        14                  10,000 Hours (with Justin Bieber)
# 15        15                                    Use This Gospel
# 16        16                                 Everything We Need
# 17        17                                          Lights Up
# 18        18                                  Hot (feat. Gunna)
# 19        19                            223's (feat. 9lokknine)
# 20        20                                            Camelot
# 21        21         Good As Hell (feat. Ariana Grande) - Remix
# 22        22      Sunflower - Spider-Man: Into the Spider-Verse
# 23        23  Take What You Want (feat. Ozzy Osbourne & Trav...
# 24        24                                             Ransom
# 25        25                                            ROXANNE
# 26        26                                             God Is
# 27        27                        Goodbyes (Feat. Young Thug)
# 28        28           Money In The Grave (Drake ft. Rick Ross)
# 29        29                                        Truth Hurts
# 30        30                             Trampoline (with ZAYN)
# ..       ...                                                ...
# 171      171                                     Sebenzela nina
# 172      172                               Dagdrome in Suburbia
# 173      173                            Going Bad (feat. Drake)
# 174      174  Hot Girl Summer (feat. Nicki Minaj & Ty Dolla ...
# 175      175          Right Back (feat. A Boogie Wit Da Hoodie)
# 176      176                          Bones (feat. OneRepublic)
# 177      177                                             Africa
# 178      178      Don't Check On Me (feat. Justin Bieber & Ink)
# 179      179                                              VIBEZ
# 180      180                                            Perfect
# 181      181                                          Big Plans
# 182      182                           Something Just Like This
# 183      183             Nights Like This (feat. Ty Dolla $ign)
# 184      184                                           Believer
# 185      185                 Summer Life (with Jake Reese & OT)
# 186      186                                         Slide Away
# 187      187                                         In My Mind
# 188      188                        Boerepompie (feat. Snotkop)
# 189      189  Let Me Go (with Alesso, Florida Georgia Line &...
# 190      190               Drive (feat. Delilah Montagu) - Edit
# 191      191                                            You Say
# 192      192                                       Shape of You
# 193      193                 Die For Me (feat. Future & Halsey)
# 194      194  Love You Tonight (feat. DJ Maphorisa, Sha Sha ...
# 195      195                            Scars To Your Beautiful
# 196      196                                   Don't Call Me Up
# 197      197                          BEST ON EARTH (feat. BIA)
# 198      198                                            Thunder
# 199      199                   Can We Pretend (feat. Cash Cash)
# 200      200                             Falling Like The Stars
#
# 0                 Artist  Streams  \
# 1           Selena Gomez  1961112
# 2             Kanye West  1732594
# 3            Post Malone  1491517
# 4           Travis Scott  1464527
# 5             Juice WRLD  1204661
# 6          Lewis Capaldi  1118953
# 7               Maroon 5  1118361
# 8              blackbear  1032214
# 9             Kanye West   947353
# 10           Tones and I   933639
# 11            Kanye West   911984
# 12          Selena Gomez   893582
# 13            Kanye West   853260
# 14            Dan + Shay   845552
# 15            Kanye West   836830
# 16            Kanye West   832597
# 17          Harry Styles   809138
# 18            Young Thug   805822
# 19             YNW Melly   800400
# 20            NLE Choppa   706982
# 21                 Lizzo   699073
# 22           Post Malone   698607
# 23           Post Malone   690544
# 24             Lil Tecca   679612
# 25        Arizona Zervas   677849
# 26            Kanye West   674839
# 27           Post Malone   671348
# 28                 Drake   667475
# 29                 Lizzo   653506
# 30                 SHAED   642385
# ..                   ...      ...
# 171      Samthing Soweto     1446
# 172    Francois van Coke     1444
# 173            Meek Mill     1440
# 174  Megan Thee Stallion     1431
# 175               Khalid     1430
# 176             Galantis     1426
# 177                 TOTO     1419
# 178          Chris Brown     1419
# 179               DaBaby     1418
# 180           Ed Sheeran     1408
# 181         Why Don't We     1407
# 182     The Chainsmokers     1392
# 183              Kehlani     1391
# 184      Imagine Dragons     1390
# 185                 Regi     1388
# 186          Miley Cyrus     1388
# 187               Dynoro     1381
# 188            Ricus Nel     1378
# 189     Hailee Steinfeld     1375
# 190         Black Coffee     1375
# 191        Lauren Daigle     1370
# 192           Ed Sheeran     1363
# 193          Post Malone     1362
# 194            Mfr Souls     1361
# 195         Alessia Cara     1357
# 196                Mabel     1355
# 197                 Russ     1350
# 198      Imagine Dragons     1350
# 199                 P!nk     1348
# 200         James Arthur     1345
#
# 0                                                  URL          Chart
# 1    https://open.spotify.com/track/1HfMVBKM75vxSfs...  United States
# 2    https://open.spotify.com/track/2QpGZOhTCHHiKmp...  United States
# 3    https://open.spotify.com/track/21jGcNKet2qwijl...  United States
# 4    https://open.spotify.com/track/3eekarcy7kvN4yt...  United States
# 5    https://open.spotify.com/track/6Gg1gjgKi2AK4e0...  United States
# 6    https://open.spotify.com/track/7qEHsqek33rTcFN...  United States
# 7    https://open.spotify.com/track/2b8fOow8UzyDFAE...  United States
# 8    https://open.spotify.com/track/7aiClxsDWFRQ0Kz...  United States
# 9    https://open.spotify.com/track/2SasoXZyv82yYgH...  United States
# 10   https://open.spotify.com/track/1rgnBhdG2JDFTbY...  United States
# 11   https://open.spotify.com/track/3JWiDGQX2eTlFvK...  United States
# 12   https://open.spotify.com/track/4yI3HpbSFSgFZtJ...  United States
# 13   https://open.spotify.com/track/39JRmdKFka1Oe09...  United States
# 14   https://open.spotify.com/track/2wrJq5XKLnmhRXH...  United States
# 15   https://open.spotify.com/track/0oPOuDmmkVp3h6p...  United States
# 16   https://open.spotify.com/track/24bnCCysWnbNRNU...  United States
# 17   https://open.spotify.com/track/2plLJpUcYPFrl1s...  United States
# 18   https://open.spotify.com/track/5Z8HZM6iQMhhqyP...  United States
# 19   https://open.spotify.com/track/4sjiIpEv617LDXa...  United States
# 20   https://open.spotify.com/track/4sWuPniHClkInYA...  United States
# 21   https://open.spotify.com/track/07Oz5StQ7GRoygN...  United States
# 22   https://open.spotify.com/track/0RiRZpuVRbi7oqR...  United States
# 23   https://open.spotify.com/track/7CZyCXKG6d5ALeq...  United States
# 24   https://open.spotify.com/track/1lOe9qE0vR9zwWQ...  United States
# 25   https://open.spotify.com/track/1ZPWWSwCkxKfqdp...  United States
# 26   https://open.spotify.com/track/6xRWoYwfwIKnT8b...  United States
# 27   https://open.spotify.com/track/6vBdBCoOhKHiYDD...  United States
# 28   https://open.spotify.com/track/5ry2OE6R2zPQFDO...  United States
# 29   https://open.spotify.com/track/5qmq61DAAOUaW8A...  United States
# 30   https://open.spotify.com/track/1iQDltZqI7BXnHr...  United States
# ..                                                 ...            ...
# 171  https://open.spotify.com/track/12shorPGh81eTyc...   South Africa
# 172  https://open.spotify.com/track/10Ql7yWoFEmRNp8...   South Africa
# 173  https://open.spotify.com/track/2IRZnDFmlqMuOrY...   South Africa
# 174  https://open.spotify.com/track/5N1o6d8zGcSZSeM...   South Africa
# 175  https://open.spotify.com/track/6PYnUsNEpYC7A4B...   South Africa
# 176  https://open.spotify.com/track/1pfgsjmxVZhoZpe...   South Africa
# 177  https://open.spotify.com/track/2374M0fQpWi3dLn...   South Africa
# 178  https://open.spotify.com/track/7ILEWkpfdK6AjH2...   South Africa
# 179  https://open.spotify.com/track/0fySG6A6qLE8IvD...   South Africa
# 180  https://open.spotify.com/track/0tgVpDi06FyKpA1...   South Africa
# 181  https://open.spotify.com/track/3eng6TJxpqjvDkx...   South Africa
# 182  https://open.spotify.com/track/6RUKPb4LETWmmr3...   South Africa
# 183  https://open.spotify.com/track/6ZRuF2n1CQxyxxA...   South Africa
# 184  https://open.spotify.com/track/0pqnGHJpmpxLKif...   South Africa
# 185  https://open.spotify.com/track/75uubllQ8LCxn54...   South Africa
# 186  https://open.spotify.com/track/44ADyYoY5liaRa3...   South Africa
# 187  https://open.spotify.com/track/0E9ZjEAyAwOXZ7w...   South Africa
# 188  https://open.spotify.com/track/46x1zSvuhlRxGi0...   South Africa
# 189  https://open.spotify.com/track/5Gu0PDLN4YJeW75...   South Africa
# 190  https://open.spotify.com/track/6X7PK2UQMUU36ux...   South Africa
# 191  https://open.spotify.com/track/6Up545NUflOiXo8...   South Africa
# 192  https://open.spotify.com/track/7qiZfU4dY1lWllz...   South Africa
# 193  https://open.spotify.com/track/2C6WXnmZ66tHhHl...   South Africa
# 194  https://open.spotify.com/track/16OxVuaZfax9fCa...   South Africa
# 195  https://open.spotify.com/track/0prNGof3XqfTvND...   South Africa
# 196  https://open.spotify.com/track/5WHTFyqSii0lmT9...   South Africa
# 197  https://open.spotify.com/track/2Xo3rLHjXfdb4av...   South Africa
# 198  https://open.spotify.com/track/1zB4vmk8tFRmM9U...   South Africa
# 199  https://open.spotify.com/track/7GfKD5B7fVAzUgD...   South Africa
# 200  https://open.spotify.com/track/395KzBy0bkb57dE...   South Africa
#
# [11395 rows x 6 columns]

# %%
# Save data as csv file 
spotify_charts.to_csv('spotify_charts.csv',index=False)
